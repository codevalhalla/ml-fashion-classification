# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.applications.xception import preprocess_input

# %%
model = keras.models.load_model("./xception_v4_39_0.894.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
test_gen = ImageDataGenerator(
    preprocessing_function=preprocess_input)

test_ds= test_gen.flow_from_directory("../data/test",
                                    target_size=  (299,299),
                                    batch_size=32,
                                    shuffle=False)
# Out:
# Found 372 images belonging to 10 classes.

# %%
model.evaluate(test_ds)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - accuracy: 0.8844 - loss: 0.3579
# [0.3579281270503998, 0.8844085931777954]

# %%
path = '../data/test/pants/52f73c9e-93da-47ae-bf67-f0e7b8216fe1.jpg'

# %%
img = load_img(path,target_size=(299,299))

# %%
import numpy as np

# %%
x = np.array(img)
X = np.array([x])
X.shape
# Out:
# (1, 299, 299, 3)

# %%
X = preprocess_input(X)

# %%
pred = model.predict(X)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 917ms/step

# %%
pred[0]
# Out:
# array([-6.9219804, -9.685806 , -0.72099  , -1.6574783, 12.017324 ,
#        -7.447838 , -7.3985844,  6.3768   , -6.200814 , -5.311629 ],
#       dtype=float32)

# %%
classes = ['dress',
 'hat',
 'longsleeve',
 'outwear',
 'pants',
 'shirt',
 'shoes',
 'shorts',
 'skirt',
 't-shirt']

# %%
proba = dict(zip(classes,pred[0]))

# %%
for i in proba:
    print(f"{i}:{proba[i]}")
# Out:
# dress:-6.921980381011963
# hat:-9.685806274414062
# longsleeve:-0.720990002155304
# outwear:-1.6574783325195312
# pants:12.017324447631836
# shirt:-7.447837829589844
# shoes:-7.398584365844727
# shorts:6.376800060272217
# skirt:-6.2008137702941895
# t-shirt:-5.311628818511963
